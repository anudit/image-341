# %%
# !wget https://nypost.com/wp-content/uploads/sites/2/2020/07/Mark_Zuckerberg.jpg
# Out:
# --2020-08-20 03:24:39--  https://nypost.com/wp-content/uploads/sites/2/2020/07/Mark_Zuckerberg.jpg
# Resolving nypost.com (nypost.com)... 192.0.66.32
# Connecting to nypost.com (nypost.com)|192.0.66.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1430572 (1.4M) [image/jpeg]
# Saving to: ‘Mark_Zuckerberg.jpg’
#
# Mark_Zuckerberg.jpg 100%[===================>]   1.36M  2.53MB/s    in 0.5s
#
# 2020-08-20 03:24:40 (2.53 MB/s) - ‘Mark_Zuckerberg.jpg’ saved [1430572/1430572]

# %%
from PIL import Image

im = Image.open("Mark_Zuckerberg.jpg")
print(im)
width, height = im.size
print(width, height)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2000x1333 at 0x7F0326C8EBA8>
# 2000 1333

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('Mark_Zuckerberg.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from skimage import io
img = io.imread('Mark_Zuckerberg.jpg', plugin='matplotlib')
img.shape
# Out:
# (1333, 2000, 3)

# %%
import numpy
f = open("Mark_Zuckerberg.jpg", "rb")
img = f.read()

file1 = open('Mark_Zuckerberg_new.jpg', 'wb') 
file1.write(img) 
file1.close()
