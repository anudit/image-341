# %%
# !wget https://picsum.photos/1000/1000 -O img1.png -q

import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # Q1

# %%
img = cv2.imread('img1.png', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rev = img_color[::-1]

fig, axs = plt.subplots(1, 2, figsize=(20,20))
axs[0].imshow(img_color)
axs[1].imshow(img_rev)
fig.show()

# %% [markdown]
# # Q2

# %%
img = cv2.imread('img1.png', 1)
cv2.imwrite('img1.jpg', img)
# Out:
# True

# %% [markdown]
# # Q3

# %%
img = cv2.imread('img1.png', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_p1 = img_color[:int(len(img_color)//2)]
img_p2 = img_color[int(len(img_color)//2):]

fig, axs = plt.subplots(1, 3, figsize=(20,20))
axs[0].imshow(img_color)
axs[1].imshow(img_p1)
axs[2].imshow(img_p2)
fig.show()

# %% [markdown]
# # Q4

# %%
img = cv2.imread('img1.png', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_neg = [[[255-pixel[0], 255-pixel[1], 255-pixel[2]] for pixel in row] for row in img_color]

fig, axs = plt.subplots(1, 2, figsize=(20,20))
axs[0].imshow(img_color)
axs[1].imshow(img_neg)
fig.show()

# %% [markdown]
# # Q5

# %%
img = cv2.imread('img1.png', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

temp = np.zeros_like(img_color, dtype=np.uint8)
circle = cv2.circle(temp, (500, 500), 650, (255,255,255), 300)

newimg= cv2.subtract(img_color, circle)
plt.imshow(newimg)

# %% [markdown]
# #Q6

# %%
# !wget https://picsum.photos/1000/1000 -O img2.png -q
# !wget https://picsum.photos/1000/1000 -O img3.png -q
# !wget https://picsum.photos/1000/1000 -O img4.png -q
img2 = cv2.imread(r'img2.png', 1)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img3 = cv2.imread(r'img3.png', 1)
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
img4 = cv2.imread(r'img4.png', 1)
img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)

fig, axs = plt.subplots(1, 3 ,figsize=(20,20))
axs[0].imshow(img2)
axs[0].set_title('Image1')
axs[1].imshow(img3)
axs[1].set_title('Image2')
axs[2].imshow(img4)
axs[2].set_title('Image2')

plt.show()

# %% [markdown]
# # Q7

# %%
img = cv2.imread('img1.png', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

scale_percent = 20
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

x_offset=y_offset=50
img_color[y_offset:y_offset+resized.shape[0], x_offset:x_offset+resized.shape[1]] = resized

plt.imshow(img_color)

# %% [markdown]
# # Q8

# %%
img = cv2.imread('img1.png', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

circle = cv2.circle(img_color, (500, 500), 100, (23,23,23), -1)

plt.imshow(img_color)

# %%
img = cv2.imread('img1.png', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
font = cv2.FONT_HERSHEY_SIMPLEX 
org = (200, 200) 
fontScale = 5
color = (0, 0, 255) 
thickness = 5

image = cv2.putText(img_color, 'Anudit', org, font,  
                   fontScale, color, thickness, cv2.LINE_AA) 
   
plt.imshow(image)

# %%
img = cv2.imread('img1.png', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

b = img_color.copy()
b[:, :, 1] = 0
b[:, :, 2] = 0

g = img_color.copy()
g[:, :, 0] = 0
g[:, :, 2] = 0

r = img_color.copy()
r[:, :, 0] = 0
r[:, :, 1] = 0


fig, axs = plt.subplots(1, 5 ,figsize=(15,15))
axs[0].imshow(img_color)
axs[0].set_title('Orginal')
axs[1].imshow(r)
axs[1].set_title('R')
axs[2].imshow(g)
axs[2].set_title('G')
axs[3].imshow(b)
axs[3].set_title('B')
axs[4].imshow(img_color)
axs[4].set_title('Merge')

plt.show()

# %% [markdown]
# # Q10

# %%
import cv2

background = cv2.imread('img1.jpg')
overlay = cv2.imread('img4.png')

l1 = cv2.addWeighted(background,0.5,overlay,1,0)

fig, axs = plt.subplots(1, 3 ,figsize=(15,15))
axs[0].imshow(background)
axs[0].set_title('Orginal')
axs[1].imshow(l1)
axs[1].set_title('Alpha = 0.5')
axs[2].imshow(overlay)
axs[2].set_title('Morphed')
# Out:
# Text(0.5, 1.0, 'Morphed')
