# %%
# !wget https://nypost.com/wp-content/uploads/sites/2/2020/07/Mark_Zuckerberg.jpg

import matplotlib.pyplot as plt
import numpy as np
import cv2
# Out:
# --2020-08-25 15:54:20--  https://nypost.com/wp-content/uploads/sites/2/2020/07/Mark_Zuckerberg.jpg
# Resolving nypost.com (nypost.com)... 192.0.66.32
# Connecting to nypost.com (nypost.com)|192.0.66.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1430572 (1.4M) [image/jpeg]
# Saving to: ‘Mark_Zuckerberg.jpg.1’
#
# Mark_Zuckerberg.jpg 100%[===================>]   1.36M  --.-KB/s    in 0.08s
#
# 2020-08-25 15:54:20 (16.7 MB/s) - ‘Mark_Zuckerberg.jpg.1’ saved [1430572/1430572]

# %% [markdown]
# # RGB to Gray-scale conversion of images

# %% [markdown]
# ## Read any RGB image as input and convert it into grayscale image using direct function/library in Python. Show input and output together using subplot function

# %%
img = cv2.imread('Mark_Zuckerberg.jpg', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img_color, cv2.COLOR_RGB2GRAY)

fig, axs = plt.subplots(1, 2)
axs[0].imshow(img_color)
axs[1].imshow(img_gray,'gray')
fig.show()

# %% [markdown]
# ## RGB to grayscale Image conversion using numpy and matplotlib only. No other special Python library can be used. Explain the steps in your own words

# %% [markdown]
# 1. Here we first read the image via openCV and convert it from BGR to RGB. We get the numpy arrays.
# 2. Then we convert each (R,G,B) pixel in to its corresponding grayscale value using Numpy.
# 3. Plot the changes using Matlplotlib.

# %%
orig = cv2.imread(r'Mark_Zuckerberg.jpg', 1)
orig = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
grayValue = 0.07 * orig[:,:,2] + 0.72 * orig[:,:,1] + 0.21 * orig[:,:,0]
gray_img = grayValue.astype(np.uint8)
fig, axs = plt.subplots(1, 2)
axs[0].imshow(orig)
axs[1].imshow(g,'gray')
fig.show()

# %% [markdown]
# # Take two images and perform Image subtraction, addition, and multiplication of those images using arrays.

# %%
# !wget https://picsum.photos/1000/1000 -O img1.png -q
# !wget https://picsum.photos/1000/1000 -O img2.png -q
img1 = cv2.imread(r'img1.png', 1)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r'img2.png', 1)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

fig, axs = plt.subplots(1, 5 ,figsize=(20,20))
axs[0].imshow(img1)
axs[0].set_title('Image1')
axs[1].imshow(img2)
axs[1].set_title('Image2')
axs[2].imshow(img1+img2)
axs[2].set_title('Sum')
axs[3].imshow(img1-img2)
axs[3].set_title('Difference')
axs[4].imshow(img1*img2)
axs[4].set_title('Product')
plt.show()

# %% [markdown]
# # Converting from one color space into another (RGB to HSV conversion)

# %%
img = cv2.imread('Mark_Zuckerberg.jpg', 1)
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(img_color, cv2.COLOR_RGB2HSV)

fig, axs = plt.subplots(1, 3)
axs[0].imshow(img)
axs[0].set_title('BGR')
axs[1].imshow(img_color)
axs[1].set_title('RGB')
axs[2].imshow(img_hsv)
axs[2].set_title('HSV')

fig.show()

# %% [markdown]
# Image resizing using bilinear, bicubic and nearest neighbour interpolation methods. What is your observation about the outputs of these methods; can you see any difference in outputs? Write it in your own words.

# %%
img = cv2.imread('Mark_Zuckerberg.jpg', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

bilinear_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_LINEAR)
img_resized = cv2.resize(img,None, fx=10, fy=10, interpolation = cv2.INTER_CUBIC)
near_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_NEAREST)

fig, axs = plt.subplots(1, 3 ,figsize=(10,10))
axs[0].imshow(bilinear_img)
axs[0].set_title('BILINEAR INTERPOLATION')
axs[1].imshow(img_resized)
axs[1].set_title('BICUBIC INTERPOLATION')
axs[2].imshow(near_img)
axs[2].set_title('NEAREST NEIGHBOUR')

fig.show()
