# %%
# !wget -q https://picsum.photos/300/300 -O img1.png

# %% [markdown]
# ## Q1

# %%
import matplotlib.pyplot as plt
from skimage.io import imread, imsave
from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import black_tophat, skeletonize, convex_hull_image
from skimage.morphology import disk, square, diamond
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte


def plot_comparison(original, filtered, filter_name):

    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 4), sharex=True,
                                   sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(filter_name)
    ax2.axis('off')


im = imread('img1.png', as_gray=True)
im = rgb2gray(im)

# %%
selem = disk(6)
eroded = erosion(im, selem)
plot_comparison(im, eroded, 'erosion')

# %%
dilated = dilation(im, selem)
plot_comparison(im, dilated, 'dilation')

# %%
opened = opening(im, selem)
plot_comparison(im, opened, 'opening')

# %%
phantom = im.copy()
phantom[10:30, 200:210] = 0

closed = closing(phantom, selem)
plot_comparison(phantom, closed, 'closing')

# %% [markdown]
# ## Q2

# %%
im = imread('mandrill_noisy.png', as_gray=True)
im = rgb2gray(im)

opened = opening(im, selem)
# plot_comparison(im, opened, 'opening')
phantom = opened.copy()
phantom[10:30, 200:210] = 0
closed = closing(phantom, selem)
plot_comparison(im, closed, 'closing')

# %% [markdown]
# ## Q3

# %%
im = imread('Fingerprint.png', as_gray=True)
im = rgb2gray(im)

opened = opening(im, selem)
plot_comparison(im, opened, 'opened')
